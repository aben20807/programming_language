# %% [markdown]
#  # programming language HW4

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

'''
w, h = 100, 7;
Matrix = [[0 for x in range(w)] for y in range(h)] 
'''
l1 = []
l2 = []
l5 = []
l6 = []
l7 = []
l8 = []
l9 = []
l10 = []
l11 = []
l12 = []
col = [x for x in range(100)]
m1 = pd.read_csv('r1.csv',names = col,index_col=False)
m2 = pd.read_csv('r2.csv',names = col,index_col=False)
m5 = pd.read_csv('r5.csv',names = col,index_col=False)
m6 = pd.read_csv('r6.csv',names = col,index_col=False)
m7 = pd.read_csv('r7.csv',names = col,index_col=False)
m8 = pd.read_csv('r8.csv',names = col,index_col=False)
m9 = pd.read_csv('r9.csv',names = col,index_col=False)
m10 = pd.read_csv('r10.csv',names = col,index_col=False)
m11 = pd.read_csv('r11.csv',names = col,index_col=False)
m12 = pd.read_csv('r12.csv',names = col,index_col=False)

print(len(m1.index))
m1 = m1/1000000
m2 = m2/1000000
m5 = m5/1000000
m6 = m6/1000000
m7 = m7/1000000
m8 = m8/1000000
m9 = m9/1000000
m10 = m10/1000000
m11 = m11/1000000
m12 = m12/1000000

#print(m1)
for i in range(len(m1.index)):
    #print(m1.iloc[i].sort_values()[5:95].mean())
    l1.append(m1.iloc[i].sort_values()[5:95].mean())
    l2.append(m2.iloc[i].sort_values()[5:95].mean())
    l5.append(m5.iloc[i].sort_values()[5:95].mean())
    l6.append(m6.iloc[i].sort_values()[5:95].mean())
    l7.append(m7.iloc[i].sort_values()[5:95].mean())
    l8.append(m8.iloc[i].sort_values()[5:95].mean())
    l9.append(m9.iloc[i].sort_values()[5:95].mean())
    l10.append(m10.iloc[i].sort_values()[5:95].mean())
    l11.append(m11.iloc[i].sort_values()[5:95].mean())
    l12.append(m12.iloc[i].sort_values()[5:95].mean())
'''
print(l1)
print(l1[27:30])

'''
#print(m10)
# Out:
# 30
# '\nprint(l1)\nprint(l1[27:30])\n\n'

# %%
import numpy as np
plt.rcParams['font.size']=10
x = np.array([l1,l2,l5,l6,l7,l8,l9,l10,l11,l12]).T
# print(x)
df = pd.DataFrame(x,  columns=list('ABEFGHIJKL'))
result = df.plot(title = 'parallel matrix computation (rust)',ylim=[0,50])
result.set_xlabel("n*n")
result.set_ylabel("ms")
#result.set_xticklabels(['10','50','100','150','200','250','300','350'])

plt.xticks([0,5,10,15,20,25,30],[r'$10$', r'$50$', r'$100$', r'$150$', r'$200$', r'$250$',r'$300$'])

fig = result.get_figure()
fig.set_size_inches(8, 5)
fig.savefig("rust.png")

# %%
ol1 = []
ol2 = []
ol5 = []
ol6 = []
ol7 = []
ol8 = []
ol10 = []
ol11 = []
ol12 = []
col = [x for x in range(100)]
o1 = pd.read_csv('o1.csv',names = col,index_col=False)
o2 = pd.read_csv('o7.csv',names = col,index_col=False)
o5 = pd.read_csv('o2.csv',names = col,index_col=False)
o6 = pd.read_csv('o8.csv',names = col,index_col=False)
o7 = pd.read_csv('o4.csv',names = col,index_col=False)
o8 = pd.read_csv('o5.csv',names = col,index_col=False)
o10 = pd.read_csv('o9.csv',names = col,index_col=False)
o11 = pd.read_csv('o6.csv',names = col,index_col=False)
o12 = pd.read_csv('o3.csv',names = col,index_col=False)

print(len(m1.index))
o1 = o1/1000000
o2 = o2/1000000
o5 = o5/1000000
o6 = o6/1000000
o7 = o7/1000000
o8 = o8/1000000
o10 = o10/1000000
o11 = o11/1000000
o12 = o12/1000000

#print(m1)
for i in range(len(o1.index)):
    #print(m1.iloc[i].sort_values()[5:95].mean())
    ol1.append(o1.iloc[i].sort_values()[5:95].mean())
    ol2.append(o2.iloc[i].sort_values()[5:95].mean())
    ol5.append(o5.iloc[i].sort_values()[5:95].mean())
    ol6.append(o6.iloc[i].sort_values()[5:95].mean())
    ol7.append(o7.iloc[i].sort_values()[5:95].mean())
    ol8.append(o8.iloc[i].sort_values()[5:95].mean())
    ol10.append(o10.iloc[i].sort_values()[5:95].mean())
    ol11.append(o11.iloc[i].sort_values()[5:95].mean())
    ol12.append(o12.iloc[i].sort_values()[5:95].mean())
# Out:
# 30

# %%
plt.rcParams['font.size']=10
ox = np.array([ol1,ol2,ol5,ol6,ol7,ol8,ol10,ol11,ol12]).T
# print(x)
df = pd.DataFrame(ox,  columns=list('ABEFGIJKL'))
result2 = df.plot(title = 'parallel matrix computation (cpp)',ylim=[0,350])
result2.set_xlabel("n*n")
result2.set_ylabel("ms")
#result.set_xticklabels(['10','50','100','150','200','250','300','350'])

plt.xticks([0,5,10,15,20,25,30],[r'$10$', r'$50$', r'$100$', r'$150$', r'$200$', r'$250$',r'$300$'])

fig2 = result2.get_figure()
fig2.set_size_inches(8, 5)
fig2.savefig("cpp.png")

# %%
jl1 = []
jl2 = []
jl5 = []
jl6 = []
jl7 = []
jl8 = []
jl10 = []
jl11 = []
jl12 = []
col = [x for x in range(100)]
j1 = pd.read_csv('out1.csv',names = col,index_col=False)
j2 = pd.read_csv('out7.csv',names = col,index_col=False)
j5 = pd.read_csv('out2.csv',names = col,index_col=False)
j6 = pd.read_csv('out8.csv',names = col,index_col=False)
j7 = pd.read_csv('out4.csv',names = col,index_col=False)
j8 = pd.read_csv('out5.csv',names = col,index_col=False)
j10 = pd.read_csv('out9.csv',names = col,index_col=False)
j11 = pd.read_csv('out6.csv',names = col,index_col=False)
j12 = pd.read_csv('out3.csv',names = col,index_col=False)

print(len(m1.index))

#print(m1)
for i in range(len(o1.index)):
    #print(m1.iloc[i].sort_values()[5:95].mean())
    jl1.append(j1.iloc[i].sort_values()[5:95].mean())
    jl2.append(j2.iloc[i].sort_values()[5:95].mean())
    jl5.append(j5.iloc[i].sort_values()[5:95].mean())
    jl6.append(j6.iloc[i].sort_values()[5:95].mean())
    jl7.append(j7.iloc[i].sort_values()[5:95].mean())
    jl8.append(j8.iloc[i].sort_values()[5:95].mean())
    jl10.append(j10.iloc[i].sort_values()[5:95].mean())
    jl11.append(j11.iloc[i].sort_values()[5:95].mean())
    jl12.append(j12.iloc[i].sort_values()[5:95].mean())
# Out:
# 30

# %%
plt.rcParams['font.size']=10
jx = np.array([jl1,jl2,jl5,jl6,jl7,jl8,jl10,jl11,jl12]).T
# print(x)
df = pd.DataFrame(jx,  columns=list('ABEFGIJKL'))
result3 = df.plot(title = 'parallel matrix computation (java)',ylim=[0,50])
result3.set_xlabel("n*n")
result3.set_ylabel("ms")
#result.set_xticklabels(['10','50','100','150','200','250','300','350'])

plt.xticks([0,5,10,15,20,25,30],[r'$10$', r'$50$', r'$100$', r'$150$', r'$200$', r'$250$',r'$300$'])

fig3 = result3.get_figure()
fig3.set_size_inches(8, 5)
fig3.savefig("java.png")

# %%
lc = []
lr = []
lc.append(ol1[len(ol1)-1])
lc.append(ol2[len(ol1)-1])
lc.append(ol5[len(ol1)-1])
lc.append(ol6[len(ol1)-1])
lc.append(ol7[len(ol1)-1])
lc.append(ol8[len(ol1)-1])
lc.append(0)
lc.append(ol10[len(ol1)-1])
lc.append(ol11[len(ol1)-1])
lc.append(ol12[len(ol1)-1])

lr.append(l1[len(ol1)-1])
lr.append(l2[len(ol1)-1])
lr.append(l5[len(ol1)-1])
lr.append(l6[len(ol1)-1])
lr.append(l7[len(ol1)-1])
lr.append(l8[len(ol1)-1])
lr.append(l9[len(ol1)-1])
lr.append(l10[len(ol1)-1])
lr.append(l11[len(ol1)-1])
lr.append(l12[len(ol1)-1])

# print(lc)
# print(lr)

X = ['A','B','E','F','G','H','I','J','K','L']
_X = np.arange(len(X))

# plt.bar(_X - 0.2, Y, 0.4)
# plt.bar(_X + 0.2, Z, 0.4)
plt.xlabel("method")
plt.ylabel("ms")
plt.title("300 matrix * 300 matrix")
plt.bar(_X - 0.2,lc,color='#005792',width=0.5,align='center',label = 'cpp')
plt.bar(_X + 0.3,lr,color='#00BBF0',width=0.5,align='center',label = 'rust')
plt.xticks(_X, X) # set labels manually
# plt.autoscale(tight=True)
plt.legend(loc='upper right')

fig4 = plt.gcf()
fig4.set_size_inches(8, 5)
fig4.savefig("bar.png")
plt.show()

# %%
lm1 = []
lm1.append(0.000188)
lm1.append(0.544598)
lm1.append(0.877262)

lm2 = []
lm2.append(73.119700)
lm2.append(54.087265)
lm2.append(50.865721)

lm3 = []
lm3.append(6601.806116)
lm3.append(3541.451284)
lm3.append(3388.073694)

plt.subplot(3,1,1)
plt.bar(['tri_loop','tri_loop(p)','strassen(p)',],lm1,width=0.4)
plt.xlabel('method')
plt.ylabel('s')
plt.title('16 matrix * 16 matrix (matlab)')

plt.subplot(3,1,2)
plt.bar(['tri_loop','tri_loop(p)','strassen(p)',],lm2,width=0.4)
plt.xlabel('method')
plt.ylabel('s')
plt.title('1024 matrix * 1024 matrix (matlab)')

plt.subplot(3,1,3)
plt.bar(['tri_loop','tri_loop(p)','strassen(p)',],lm3,width=0.4)
plt.xlabel('method')
plt.ylabel('s')
plt.title('4096 matrix * 4096 matrix (matlab)')

fig5 = plt.gcf()
fig5.set_size_inches(3.5, 16)
fig5.savefig("matlab.png")
plt.show()

# %%
lr1 = []
lr1.append(0.000336396)
lr1.append(0.002577983)
lr1.append(0.000250358)
lr1.append(0.001142832)

lr2 = []
lr2.append(1.731037843)
lr2.append(1.302979579)
lr2.append(6.556949608)
lr2.append(6.255524012)

lr3 = []
lr3.append(87.741757400)
lr3.append(181.788059114)
lr3.append(411.457651210)
lr3.append(599.927562565)

plt.subplot(3,1,1)
a = plt.bar(['j(r)','k(r)','j(c)','k(c)'],lr1,width=0.4)
a[0].set_color('#93deff')
a[1].set_color('#93deff')
plt.xlabel('method')
plt.ylabel('s')
plt.title('16 matrix * 16 matrix (r cpp)')

plt.subplot(3,1,2)
b =plt.bar(['j(r)','k(r)','j(c)','k(c)'],lr2,width=0.4)
b[0].set_color('#93deff')
b[1].set_color('#93deff')
plt.xlabel('method')
plt.ylabel('s')
plt.title('1024 matrix * 1024 matrix (r cpp)')

plt.subplot(3,1,3)
c = plt.bar(['j(r)','k(r)','j(c)','k(c)'],lr3,width=0.4)
c[0].set_color('#93deff')
c[1].set_color('#93deff')
plt.xlabel('method')
plt.ylabel('s')
plt.title('4096 matrix * 4096 matrix (r cpp)')

fig5 = plt.gcf()
fig5.set_size_inches(5, 16)
fig5.savefig("rust_cpp.png")
plt.show()

# %%
lj1 = []
lj1.append(0.000083729)
lj1.append(0.000075756)

lj2 = []
lj2.append(0.672612759)
lj2.append(0.682691698)


plt.subplot(2,1,1)
plt.bar(['j(j)','k(j)'],lj1,width=0.3)
plt.xlabel('method')
plt.ylabel('s')
plt.title('16 matrix * 16 matrix (java)')

plt.subplot(2,1,2)
plt.bar(['j(j)','k(j)'],lj2,width=0.3)
plt.xlabel('method')
plt.ylabel('s')
plt.title('1024 matrix * 1024 matrix (java)')


fig5 = plt.gcf()
fig5.set_size_inches(5.5, 10)
fig5.savefig("java.png")
plt.show()
